# %% [markdown]
# # Symbolic computation of Sine Ridge:
#
# The goal is to create a vector field that has a closed-form expression for the FTLE field, but already displays nontrivial spatial dependence.
#
# Start with a simple system that has a closed form expression for the flowmap (and also the FTLE field).
# $$\dot{x} = -x +x^3 \\ \dot{y} = 1 $$
# This system can be integrated, and it can be seen that it has an FTLE ridge along the $y$ axis.
#
# Now introduce a coordinate transform
#
# $$
# (x,y) = w(u, v).
# $$
#
# The vector field in the new coordinates can be obtained by differentiating the expression:
# $$
# \dot{(w(u,v))} = f(w(u,v))
# $$
#
# $$
# \nabla w \dot{(u,v)} = f(w(u,v)) \\
# \dot{(u,v)} = (\nabla w)^{-1} f(w(u,v))
# $$
#
# If the flow map of the $(x,y)$ system is $F^\tau (x_0,y_0)$, the transformed system's becomes
#
# $$
# (F^\tau(u_0,v_0))' = w^{-1}\circ F^\tau \circ w(u_0,v_0)
# $$
#
# For the particular example, we have
#
# $$F^\tau(x_0,y_0) = \left(\frac{x_0}{\sqrt{x_0^2 + (1-x_0^2)e^{-2\tau}}}, y_0 + \tau\right)$$.
#
# Let's introduce the transformation
# $$
# (x,y) := w(u,v) = (u - \sin v, v) \\
# w^{-1}(x,y) = (x + \sin y, y).
# $$
#
# Under this, the flow map transforms into
#
# $$
# (F^\tau(u_0,v_0))' = \left( \frac{u_0 - \sin v_0}{\sqrt{(u_0 - \sin v_0)^2 + [1-(u_0 -\sin v_0)^2]e^{-2\tau}}} + \sin (v_0 + \tau), v_0 + \tau \right)
# $$
#
# From this, we can calculate the flow map gradient, and the Cauchy-Green strain tensor
#
#
# $\nabla (F^\tau(u_0,v_0))'$ =
# \begin{bmatrix}
#     \frac{\partial (F^\tau(u_0,v_0))'_1}{\partial u_0} & \frac{\partial (F^\tau(u_0,v_0))'_1}{\partial v_0} \\
#     \frac{\partial (F^\tau(u_0,v_0))'_2}{\partial u_0} & \frac{\partial (F^\tau(u_0,v_0))'_2}{\partial v_0}
# \end{bmatrix}
#
# $$
# C^\tau(u_0,v_0) = [\nabla (F^\tau(u_0,v_0))']^T\nabla (F^\tau(u_0,v_0))'.
# $$
#
# Its maximal eigenvalue gives the FTLE field:
# $$
# \lambda_2 = \frac{\text{tr}(C) + \sqrt{(\text{tr}(C)^2 - 4\text{det}(C)}}{2} \\
# \text{FTLE}(\tau, u_0,v_0) = \frac{\text{log} \lambda_2}{2 \tau}
# $$

# %%
from sympy import init_printing
init_printing()
import numpy as np

import matplotlib.pyplot as plt

# %%
from sympy import init_session
init_session()
# Out:
# IPython console for SymPy 1.4 (Python 3.7.4-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
u, v, t1, t2 = symbols('u v t1 t2')
def FlowMap1(u, v,t1, t2):
    return (u-sin(v))*exp(-(t2-t1))+ sin(v + (t2-t1))
FlowMapX = FlowMap1(u, v, t1, t2)

def FlowMap2(u,v,t1, t2):
    return v + t2 - t1
FlowMapY = FlowMap2(u, v, t1, t2)

# %% [markdown]
# $$
# F(u_0,v_0,t, t_0)_1 =
# $$

# %%
FlowMapX
# Out:
#               t₁ - t₂
# (u - sin(v))⋅ℯ        + sin(-t₁ + t₂ + v)

# %% [markdown]
# $$
# F(u_0,v_0,t, t0)_2 =
# $$

# %%
FlowMapY
# Out:
# -t₁ + t₂ + v

# %%
fxx = simplify(diff(FlowMapX, u))
fxy = simplify(diff(FlowMapX, v))
fyx = diff(FlowMapY, u)
fyy = diff(FlowMapY, v)

# %% [markdown]
# Flowmap Gradient is

# %%
dF = Matrix([[fxx, fxy], [fyx, fyy]])
dF
# Out:
# ⎡ t₁ - t₂     t₁ - t₂                           ⎤
# ⎢ℯ         - ℯ       ⋅cos(v) + cos(-t₁ + t₂ + v)⎥
# ⎢                                               ⎥
# ⎣   0                        1                  ⎦

# %% [markdown]
# Cauchy Green tensor

# %%
C = dF.T*dF
C
# Out:
# ⎡                   2⋅t₁ - 2⋅t₂                    ⎛   t₁ - t₂
# ⎢                  ℯ                               ⎝- ℯ       ⋅cos(v) + cos(-t
# ⎢
# ⎢
# ⎢⎛   t₁ - t₂                           ⎞  t₁ - t₂    ⎛   t₁ - t₂
# ⎣⎝- ℯ       ⋅cos(v) + cos(-t₁ + t₂ + v)⎠⋅ℯ           ⎝- ℯ       ⋅cos(v) + cos(
#
#            ⎞  t₁ - t₂⎤
# ₁ + t₂ + v)⎠⋅ℯ       ⎥
#                      ⎥
#               2      ⎥
#              ⎞       ⎥
# -t₁ + t₂ + v)⎠  + 1  ⎦

# %% [markdown]
# Eigenvalues, calculating it explicitly with the trace-determinant formula

# %%
tr = trace(C)
tr = simplify(tr)
determ = det(C)
determ = simplify(determ)

# %%
lambdaMax = (tr + sqrt(tr**2 - 4*determ))/2

# %%
lambdaMax
# Out:
#                                               ________________________________
#                                              ╱
#                                      2      ╱  ⎛
# ⎛ t₁ - t₂                           ⎞      ╱   ⎜⎛ t₁ - t₂
# ⎝ℯ       ⋅cos(v) - cos(-t₁ + t₂ + v)⎠    ╲╱    ⎝⎝ℯ       ⋅cos(v) - cos(-t₁ + t
# ────────────────────────────────────── + ─────────────────────────────────────
#                   2
#
# _______________________________________________
#                             2
#        2                   ⎞
#       ⎞     2⋅t₁ - 2⋅t₂    ⎟       2⋅t₁ - 2⋅t₂     2⋅t₁ - 2⋅t₂
# ₂ + v)⎠  + ℯ            + 1⎠  - 4⋅ℯ               ℯ              1
# ─────────────────────────────────────────────── + ──────────── + ─
#     2                                                  2         2

# %%
f = lambdify((u,v,tau,s), lambdaMax, 'numpy')

# %% [markdown]
# Creating meshgrid for visuals. Display on a grid of 1000 by 1000.

# %%
nx, ny = (100, 100)
u = np.linspace(-2, 2,nx)
v = np.linspace(-4,4,ny)
U, V = np.meshgrid(u,v)

# %% [markdown]
# Calculating FTLE values for $t_0=0, t=2$. Saving the result in a matrix for MATLAB processing

# %%
time = 2
FTLE = np.log(f(U,V, time, 0))/(2*time)

# %%
# %matplotlib inline

# %%
plt.imshow(FTLE)

# %% [markdown]
# ## Transformation of the vectorfield
#
# The vector field transforms according to
#
# $$
# \dot{(u,v)} = (\nabla w)^{-1} f(w(u,v)).
# $$
#
# Substituting the specific transformation and original vector fields:
#
# $$
# \nabla w =$$
# \begin{bmatrix}
#     1 & -cos v \\
#     0 & 1
# \end{bmatrix}
# $$(\nabla w)^{-1} =$$
# \begin{bmatrix}
#     1 & cos v \\
#     0 & 1
# \end{bmatrix}
#
# $$
# \dot{u} = u - \sin v - (u - \sin v)^3 + \cos v \\
# \dot{v} = 1
# $$

# %%
finiteDiff = np.loadtxt('FTLE_finiteDiff.txt')

# %% [markdown]
# Displaying the difference between the analytic and the finite difference FTLE fields

# %%
plt.imshow(np.abs(finiteDiff-FTLE))
plt.colorbar()

# %%
np.average(np.abs(finiteDiff-FTLE))
# Out:
# 2.6475142871501463e-07

# %% [markdown]
# # Model Sensitvity
#
# $$
# \text{MS}^\tau (u_0,v_0) = \int_0^\tau \sqrt{\lambda_2[u(s),v(s)]} ds
# $$

# %%
u0 = Symbol('u0')
v0 = Symbol('v0')
s = Symbol('s')
t = Symbol('t')
t0 = Symbol('t0')
us = FlowMapX.subs([(u, u0), (v, v0), (t1, t0), (t2, s)])
vs = FlowMapY.subs([(u, u0), (v, v0), (t1, t0), (t2, s)])

# %%
FlowMapX.free_symbols
# Out:
# {t₁, t₂, u, v}

# %%
us
# Out:
#                 -s + t₀
# (u₀ - sin(v₀))⋅ℯ        + sin(s - t₀ + v₀)

# %%
lambdaMax
# Out:
#                                               ________________________________
#                                              ╱
#                                      2      ╱  ⎛
# ⎛ t₁ - t₂                           ⎞      ╱   ⎜⎛ t₁ - t₂
# ⎝ℯ       ⋅cos(v) - cos(-t₁ + t₂ + v)⎠    ╲╱    ⎝⎝ℯ       ⋅cos(v) - cos(-t₁ + t
# ────────────────────────────────────── + ─────────────────────────────────────
#                   2
#
# _______________________________________________
#                             2
#        2                   ⎞
#       ⎞     2⋅t₁ - 2⋅t₂    ⎟       2⋅t₁ - 2⋅t₂     2⋅t₁ - 2⋅t₂
# ₂ + v)⎠  + ℯ            + 1⎠  - 4⋅ℯ               ℯ              1
# ─────────────────────────────────────────────── + ──────────── + ─
#     2                                                  2         2

# %%
lambdaAlongTraj = lambdaMax.subs([(u,us), (v,vs), (t1,s), (t2, t)])

# %%
lambdaAlongTraj
# Out:
#                                                      _________________________
#                                                     ╱
#                                             2      ╱  ⎛
# ⎛ s - t                                    ⎞      ╱   ⎜⎛ s - t
# ⎝ℯ     ⋅cos(s - t₀ + v₀) - cos(t - t₀ + v₀)⎠    ╲╱    ⎝⎝ℯ     ⋅cos(s - t₀ + v₀
# ───────────────────────────────────────────── + ──────────────────────────────
#                       2
#
# _________________________________________________________
#                                         2
#                      2                 ⎞
#                     ⎞     2⋅s - 2⋅t    ⎟       2⋅s - 2⋅t     2⋅s - 2⋅t
# ) - cos(t - t₀ + v₀)⎠  + ℯ          + 1⎠  - 4⋅ℯ             ℯ            1
# ───────────────────────────────────────────────────────── + ────────── + ─
#              2                                                  2        2

# %%
integrate(lambdaAlongTraj, (s, t0, t))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-fd833a5fa3b3> in <module>
# ----> 1 integrate(lambdaAlongTraj, (s, t0, t))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1475
#    1476     if isinstance(integral, Integral):
# -> 1477         return integral.doit(**doit_flags)
#    1478     else:
#    1479         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     539                 else:
#     540                     antideriv = self._eval_integral(
# --> 541                         function, xab[0], **eval_kwargs)
#     542                     if antideriv is None and meijerg is True:
#     543                         ret = try_meijerg(function, xab)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds)
#     996                     try:
#     997                         if conds == 'piecewise':
# --> 998                             h = heurisch_wrapper(g, x, hints=[])
#     999                         else:
#    1000                             h = heurisch_(g, x, hints=[])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     130
#     131     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 132                    unnecessary_permutations)
#     133     if not isinstance(res, Basic):
#     134         return res
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     703
#     704         if solution is None:
# --> 705             solution = _integrate()
#     706     else:
#     707         solution = _integrate()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     691         except ValueError:
#     692             raise PolynomialError
# --> 693         solution = solve_lin_sys(numer.coeffs(), coeff_ring, _raw=False)
#     694
#     695         if solution is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/solvers.py in solve_lin_sys(eqs, ring, _raw)
#      33
#      34     # transform from equations to matrix form
# ---> 35     matrix = eqs_to_matrix(eqs, ring)
#      36
#      37     # solve by row-reduction
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/solvers.py in eqs_to_matrix(eqs, ring)
#      15     for j, e_j in enumerate(eqs):
#      16         for i, x_i in enumerate(xs):
# ---> 17             M[j, i] = e_j.coeff(x_i)
#      18         M[j, -1] = -e_j.coeff(1)
#      19
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/rings.py in coeff(self, element)
#    1714
#    1715         """
# -> 1716         if element == 1:
#    1717             return self._get_coeff(self.ring.zero_monom)
#    1718         elif isinstance(element, self.ring.dtype):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/rings.py in __eq__(p1, p2)
#     677             return False
#     678         else:
# --> 679             return p1.get(p1.ring.zero_monom) == p2
#     680
#     681     def __ne__(p1, p2):
#
# KeyboardInterrupt:

# %%
lambdaAlongTraj.free_symbols
# Out:
# {s, t, t₀, v₀}

# %%
lambdaAlongTrajNumeric = lambdify((s,t,t0,u0,v0), lambdaAlongTraj, 'numpy')

# %%
integrate_times =np.linspace(0, 2, 10)
values = np.zeros((nx,ny,10))

# %%
nx, ny = (100, 100)
unum = np.linspace(-2, 2,nx)
vnum = np.linspace(0,4,ny)
U, V = np.meshgrid(unum,vnum)

# %% [markdown]
# The pullback-FTLE is integrated:
#
# $$
# \text{MS}^\tau (u_0,v_0) = \int_0^\tau \sqrt{\lambda_2[u(s),v(s)]} ds = \int_0^\tau f(u_0,v_0,s,\tau) ds
# $$
# Checking that we recover the FTLE field as:
# $$
# \text{log}(f(u_0,v_0,0,\tau))/\tau = FTLE^\tau(u_0,v_0).
# $$

# %%
lambdaAlongTrajNumeric(0,2,0,U,V)
# Out:
# array([[1.10918086, 1.10918086, 1.10918086, ..., 1.10918086, 1.10918086,
#         1.10918086],
#        [1.06105457, 1.06105457, 1.06105457, ..., 1.06105457, 1.06105457,
#         1.06105457],
#        [1.02626634, 1.02626634, 1.02626634, ..., 1.02626634, 1.02626634,
#         1.02626634],
#        ...,
#        [2.02227168, 2.02227168, 2.02227168, ..., 2.02227168, 2.02227168,
#         2.02227168],
#        [2.07227844, 2.07227844, 2.07227844, ..., 2.07227844, 2.07227844,
#         2.07227844],
#        [2.10925986, 2.10925986, 2.10925986, ..., 2.10925986, 2.10925986,
#         2.10925986]])

# %%
ftle2 = lambdaAlongTrajNumeric(0,2,0,U,V)
ftle2 = np.log(ftle2)/4
plt.imshow(ftle2)
plt.colorbar()

# %%
lambdaAlongTrajNumeric
# Out:
# <function _lambdifygenerated(s, t, t0, u0, v0)>

# %% [markdown]
# Evaluating the function at fixed time instants

# %%
for i in range(10):
    values[:,:,i] = np.sqrt(lambdaAlongTrajNumeric(integrate_times[i],2,0,U,V))

# %%
integrate_times[9]
# Out:
# 2.0

# %%
plt.imshow(values[:,:,9]) ##Checking that we recover the FTLE field again

# %% [markdown]
# Computing the model sensitivity through numerical integration

# %%
MS = np.trapz(values, x = integrate_times, axis = 2)

# %%
plt.imshow(MS)
plt.colorbar()

# %% [markdown]
# Loading numerical results from matlab:

# %%
MSFiniteDiff = np.loadtxt('MS_finiteDiff.txt')
MSFullFiniteDiff = np.loadtxt('MSFull_finiteDiff.txt')

# %%
plt.imshow(MSFiniteDiff)
plt.title("Difference between analytic and Finite Difference Model Sens. fields")
plt.colorbar()

# %%
plt.figure(figsize=(6,25))
for i in range(10):
    time = 0.2*(i+1)
    pbFTLE = np.loadtxt('benchmark/MS_finiteDiff_%s.txt' %(i+1))
    plt.subplot(10, 3, i*3+1)
    plt.imshow(pbFTLE)
    plt.colorbar()
    plt.subplot(10,3,i*3+2)
    pbFTLEanalytic = np.sqrt(lambdaAlongTrajNumeric(integrate_times[i],2,0,U,V))
    plt.imshow(pbFTLEanalytic)
    plt.colorbar()
    plt.subplot(10,3,i*3+3)
    plt.imshow(pbFTLEanalytic - pbFTLE)
    plt.colorbar()
